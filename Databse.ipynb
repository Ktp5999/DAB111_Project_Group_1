# %%
# import necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
con = sqlite3.connect('Bank.db')
cursor = con.cursor()

# %%
#import dataset
df = pd.read_csv("C:/Users/Lenovo/Downloads/bank_dataset.csv")

# %%
df.head(10)
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.to_sql('bank_data',con,index=False,if_exists='append')

# %%
results = cursor.execute("SELECT * FROM bank_data").fetchall()

# %%
pd.DataFrame(results)
# Out:
#         0            1        2                    3        4    5    6   \
# 0       56    housemaid  married             basic.4y       no   no   no
# 1       57     services  married          high.school  unknown   no   no
# 2       37     services  married          high.school       no  yes   no
# 3       40       admin.  married             basic.6y       no   no   no
# 4       56     services  married          high.school       no   no  yes
# ...     ..          ...      ...                  ...      ...  ...  ...
# 164747  73      retired  married  professional.course       no  yes   no
# 164748  46  blue-collar  married  professional.course       no   no   no
# 164749  56      retired  married    university.degree       no  yes   no
# 164750  44   technician  married  professional.course       no   no   no
# 164751  74      retired  married  professional.course       no  yes   no
#
#                7    8    9   ...  11   12  13           14   15      16    17  \
# ...

# %%
pd_results = pd.read_sql_query("SELECT * FROM bank_data", con)
pd_results
# Out:
#         age          job  marital            education  default housing loan  \
# 0        56    housemaid  married             basic.4y       no      no   no
# 1        57     services  married          high.school  unknown      no   no
# 2        37     services  married          high.school       no     yes   no
# 3        40       admin.  married             basic.6y       no      no   no
# 4        56     services  married          high.school       no      no  yes
# ...     ...          ...      ...                  ...      ...     ...  ...
# 164747   73      retired  married  professional.course       no     yes   no
# 164748   46  blue-collar  married  professional.course       no      no   no
# 164749   56      retired  married    university.degree       no     yes   no
# 164750   44   technician  married  professional.course       no      no   no
# 164751   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
# Bar plot of job details
plt.figure(figsize=(10, 6))
colors = ('blue','red','pink','green','purple','purple','purple','purple','purple','purple','purple','purple')
(df.job.value_counts(normalize = True)*100).plot.bar(color=colors,title = 'Bar plot for Job')
# Out:
# <AxesSubplot:title={'center':'Bar plot for Job'}>

# %%
# Plot histogram of Age
plt.figure(figsize=(10, 6))
sns.histplot(df['age'],  bins=10, kde = True)
plt.title('Age Distribution of Clients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
